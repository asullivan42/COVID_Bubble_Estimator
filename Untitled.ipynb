# %%
import pandas as pd
from sodapy import Socrata
import pandas as pd

# %%
# Open up our data from CDC.gov with my API_Token
with open("APP_TOKEN.txt",'r') as f:
    API_TOKEN=f.read()
client = Socrata("data.cdc.gov", API_TOKEN)

# %%
for n in range(1):
    if n==0:
        results=client.get("8xkx-amqh", limit=100000, offset=100000*n)
        results_df3 = pd.DataFrame.from_records(results)
    else:
        results=client.get("8xkx-amqh", limit=100000, offset=100000*n)
        results_df3.append(pd.DataFrame.from_records(results))      
results_df3
# Out:
#                           date   fips mmwr_week       recip_county  \
# 0      2022-04-20T00:00:00.000  53033        16        King County
# 1      2022-04-20T00:00:00.000  55023        16    Crawford County
# 2      2022-04-20T00:00:00.000  12131        16      Walton County
# 3      2022-04-20T00:00:00.000  13001        16     Appling County
# 4      2022-04-20T00:00:00.000  13035        16       Butts County
# ...                        ...    ...       ...                ...
# 99995  2022-03-21T00:00:00.000  31073        12      Gosper County
# 99996  2022-03-21T00:00:00.000  31101        12       Keith County
# 99997  2022-03-21T00:00:00.000  35005        12      Chaves County
# 99998  2022-03-21T00:00:00.000  35028        12  Los Alamos County
# 99999  2022-03-21T00:00:00.000  35043        12    Sandoval County
#
#       recip_state completeness_pct administered_dose1_recip  \
# 0              WA               96                  2000651
# ...

# %%
columns=results_df3.columns

# %%
results=[]
for n in range(17):
    print(f"Getting record {n+1}")
    results.extend(client.get("8xkx-amqh", limit=100000, offset=100000*n))
    print(np.size(results))
results_df=pd.DataFrame(results)
# Out:
# Getting record 1
# 100000
# Getting record 2
# 200000
# Getting record 3
# 300000
# Getting record 4
# 400000
# Getting record 5
# 500000
# Getting record 6
# 600000
# Getting record 7
# 700000
# Getting record 8
# 800000
# Getting record 9
# 900000
# Getting record 10
# 1000000
# Getting record 11
# 1100000
# Getting record 12
# 1200000
# Getting record 13
# 1300000
# Getting record 14
# 1400000
# Getting record 15
# 1500000
# Getting record 16
# 1600000
# Getting record 17
# 1621285

# %%
results_df.to_csv('./data/complete_vaccine_rate.csv')

# %%
results1=client.get("8xkx-amqh", limit=100000, offset=100000*0)
results_df3 = pd.DataFrame.from_records(results1)
results_df3
# Out:
#                           date   fips mmwr_week       recip_county  \
# 0      2022-04-20T00:00:00.000  53033        16        King County
# 1      2022-04-20T00:00:00.000  55023        16    Crawford County
# 2      2022-04-20T00:00:00.000  12131        16      Walton County
# 3      2022-04-20T00:00:00.000  13001        16     Appling County
# 4      2022-04-20T00:00:00.000  13035        16       Butts County
# ...                        ...    ...       ...                ...
# 99995  2022-03-21T00:00:00.000  31073        12      Gosper County
# 99996  2022-03-21T00:00:00.000  31101        12       Keith County
# 99997  2022-03-21T00:00:00.000  35005        12      Chaves County
# 99998  2022-03-21T00:00:00.000  35028        12  Los Alamos County
# 99999  2022-03-21T00:00:00.000  35043        12    Sandoval County
#
#       recip_state completeness_pct administered_dose1_recip  \
# 0              WA               96                  2000651
# ...

# %%
(1999897/2252782)*100
# Out:
# 88.77454631650998

# %%
results1=client.get("8xkx-amqh", limit=100000, offset=100000*1)
results_df4 = pd.DataFrame.from_records(results1)
results_df4
# Out:
#                           date   fips mmwr_week       recip_county  \
# 0      2022-03-21T00:00:00.000  39089        12     Licking County
# 1      2022-03-21T00:00:00.000  39129        12    Pickaway County
# 2      2022-03-21T00:00:00.000  39137        12      Putnam County
# 3      2022-03-21T00:00:00.000  39143        12    Sandusky County
# 4      2022-03-21T00:00:00.000  40127        12  Pushmataha County
# ...                        ...    ...       ...                ...
# 99995  2022-02-19T00:00:00.000  29029         7      Camden County
# 99996  2022-02-19T00:00:00.000  20075         7    Hamilton County
# 99997  2022-02-19T00:00:00.000  04021         7       Pinal County
# 99998  2022-02-19T00:00:00.000  29185         7   St. Clair County
# 99999  2022-02-19T00:00:00.000  06045         7   Mendocino County
#
#       recip_state completeness_pct administered_dose1_recip  \
# 0              OH             98.6                   100866
# ...

# %%
print(type(results_df3),type(results_df4))
print(type(results1),type(results2))
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.frame.DataFrame'>
# <class 'list'> <class 'list'>

# %%
pd.concat([results_df3,results_df4]).reset_index()
# Out:
#         index                     date   fips mmwr_week      recip_county  \
# 0           0  2022-04-20T00:00:00.000  53033        16       King County
# 1           1  2022-04-20T00:00:00.000  55023        16   Crawford County
# 2           2  2022-04-20T00:00:00.000  12131        16     Walton County
# 3           3  2022-04-20T00:00:00.000  13001        16    Appling County
# 4           4  2022-04-20T00:00:00.000  13035        16      Butts County
# ...       ...                      ...    ...       ...               ...
# 199995  99995  2022-02-19T00:00:00.000  29029         7     Camden County
# 199996  99996  2022-02-19T00:00:00.000  20075         7   Hamilton County
# 199997  99997  2022-02-19T00:00:00.000  04021         7      Pinal County
# 199998  99998  2022-02-19T00:00:00.000  29185         7  St. Clair County
# 199999  99999  2022-02-19T00:00:00.000  06045         7  Mendocino County
#
#        recip_state completeness_pct administered_dose1_recip  \
# ...

# %%
results0=client.get("8xkx-amqh", limit=100000, offset=100000*0)
results1=client.get("8xkx-amqh", limit=100000, offset=100000*1)

# %%
results0.extend(results1)

# %%
pd.DataFrame(results0)
# Out:
#                            date   fips mmwr_week      recip_county  \
# 0       2022-04-20T00:00:00.000  53033        16       King County
# 1       2022-04-20T00:00:00.000  55023        16   Crawford County
# 2       2022-04-20T00:00:00.000  12131        16     Walton County
# 3       2022-04-20T00:00:00.000  13001        16    Appling County
# 4       2022-04-20T00:00:00.000  13035        16      Butts County
# ...                         ...    ...       ...               ...
# 299995  2022-02-19T00:00:00.000  29029         7     Camden County
# 299996  2022-02-19T00:00:00.000  20075         7   Hamilton County
# 299997  2022-02-19T00:00:00.000  04021         7      Pinal County
# 299998  2022-02-19T00:00:00.000  29185         7  St. Clair County
# 299999  2022-02-19T00:00:00.000  06045         7  Mendocino County
#
#        recip_state completeness_pct administered_dose1_recip  \
# 0               WA               96                  2000651
# ...
