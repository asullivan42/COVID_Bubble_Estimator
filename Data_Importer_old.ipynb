# %% [markdown]
# # This is where I am experimenting with how to call and download the data from datahub's Covid-19 database
#
# **The location of the data site is https://datahub.io/core/covid-19#data**
#
# **The files are in CSV, JSON and ZIP file formats**
#
# US data is located at /core/covid-19/r/us_confirmed.cvs (or .json)
# US data is located at /core/covid-19/r/us_deaths.cvs (or .json)

# %%
import bs4 # BeautifulSoup an HTML parser
import os # library for saving the files within my systm
import re # regular expression library for finding data within the data
import requests # Downloads data from the web

# %%
# This is the file name that I save to my machine from the website so I'm not puling requests all the time
file_name = "covid-19-data.html" 
# website of the data
base_url = "https://datahub.io/core/covid-19#data" 
#Can try to make an OOP to incorperate these two variables into it for doing the rest of the code

# %%
## Code to search the datahub website to find and download the latest data.
## This can of course be addressed manually but for practice this code would 
## help me search for the link to download the data

## This can of course be addressed manually but for practice this code would 
## help me search for the link to download the data

if os.path.isfile(file_name): # may wish to delete this after the code has run or compare dates
    print(f"Using locally cached data from {file_name}") 
    with open(file_name, encoding='utf-8') as file:
        html_text = file.read()
else:
    print(f"Loading data from {base_url}")
    req = requests.get(base_url)
    req.raise_for_status()
    html_text = req.text
    with open(file_name, "w", encoding='utf-8') as file:
        file.write(html_text)
res = bs4.BeautifulSoup(html_text, "lxml")

# %% [markdown]
# **Trying out the idea of making a class to do the web scraping for me.**
#
# Trying to make tools not single use code

# %%
# What would the class look like to turn this into a tool instead of a single use code?
class WebScrape:
    def __init__(self,file_name,base_url):
        self.name = name
        self.file_name = file_name
        self.base_url = base_url
        
    def Load:
        if os.path.isfile(file_name): # may wish to delete this after the code has run or compare dates
        print(f"Using locally cached data from {file_name}") 
        with open(file_name, encoding='utf-8') as file:
            html_text = file.read()
        else:
            print(f"Loading data from {base_url}")
            req = requests.get(base_url)
            req.raise_for_status()
            html_text = req.text
            with open(file_name, "w", encoding='utf-8') as file:
                file.write(html_text)
        res = bs4.BeautifulSoup(html_text, "lxml")

# %%
links = list(res.select('.download > a'))# selects "a href" tags underneath .downlads with the CSS selectors
links #This does take specific knowlege on how this particular website is setup and not code to be used generally

# %%
# Okay now I have the locations of the files... now what?  
# First I have to pull out the address from the rest of the files under the <a /a> heading
File_links= list(re.findall(r'"([^"]*)"', str(links)))
File_links

# %%
#Next is do I set something that lets one choose what to download?  .csv? .json? .zip?
while True:
    File_Type= input ('What File Type do you wish to download? (.csv, .json, .zip)' )
    if '.csv' in File_Type or '.json' in File_Type or '.zip' in File_Type:
        print ('File type accepted')
        break
    else:
        print ("Wrong File Type!")
        continue

# %%
# then I need to add back in the full address of the file location.
addresses=[]
for Type in File_links:
    if File_Type in Type:
        print ('http://datahub.io'+Type)
        addresses.append ('http://datahub.io'+Type)

# %%
# This is an alternate way to do this.
addresses=[]
for Type in File_links:
    if Type.endswith(File_Type):
        print ('http://datahub.io'+Type)
        addresses.append ('http://datahub.io'+Type)

# %%
# how to get just the file name so I can save the file?
File_name=[]
for Type in addresses:
    File_name.append(os.path.basename(Type)) #os.path gets either the path or the file name (aka basename)
File_name

# %%
for File in addresses:
    response = requests.get(File)# downloads the csv file
    print(f"Downloading {File}")  # Updates us as to the status of the file (I could have it count down)
    with open(os.path.join(os.path.basename(File)), 'wb') as f: # creates a file to write to
        f.write(response.content) #writes the data to the file
print ('Done')

# %% [markdown]
# **That is one way... Here is another**

# %%
# Another way to get the files is to look for all a tags with href and a .csv
quotes = []
for quote in res.select("a[href$='.csv']"):
    quotes.append(quote)

# %%
# Make a set (to remove duplicates) of the text within the " "
Files_quotes = set (re.findall(r'"([^"]*)"', str(quotes))) 
Files_quotes

# %%
# This method tries to select for css codes which start with a href and end with .csv 
# It's a more general approach to finding the file locations and doesn't use a for loop
if File_Type =='.csv':
    links_href=res.select("a[href$='.csv']")
elif File_Type =='.json':
    links_href=res.select("a[href$='.json']")
else:
    links_href=res.select("a[href$='.zip']")
links_href

# %%
# Make a set (to remove duplicates) of the text within the " "
Files_href = set (re.findall(r'"([^"]*)"', str(links_href))) 
Files_href

# %% [markdown]
# **That grabs some things which are not .csv**

# %%
#this alteration will get the addresses of all the files knowing the starting address
Files_csv = set (re.findall(r'"/core/covid-19/r/([^"]*)"', str(links_href))) 
Files_csv

# %%
#This method works too, but I have to add back in a lot of the file path by hand
for address in Files_csv:
    File_path = 'https://datahub.io/core/covid-19/r/'+address
    print (File_path)

# %%
#This bit of code works to download the file to my computer to use.
#The nice thing about this way is I can use the csv file name as the file name too
for address in Files_csv:
    File_path = 'https://datahub.io/core/covid-19/r/'+ address
    response = requests.get(File_path)# downloads the csv file
    with open(os.path.join(address), 'wb') as f: # creates a file to write to
        f.write(response.content) #writes the data to the file

# %% [markdown]
# # Next step is to start combing through the data

# %% [markdown]
# # CDC Databases for COVID related Deaths

# %%
# Provisional COVID-19 Death Counts in the United States by County NCHS
"https://data.cdc.gov/resource/kn79-hsxy.json"

# United States COVID-19 Cases and Deaths by State over Time Case Surveillance
"https://data.cdc.gov/resource/9mfq-cb36.json"

# Distribution of COVID-19 Deaths and Populations, by Jurisdiction, Age, and Race and Hispanic Origin NCHS
"https://data.cdc.gov/resource/jwta-jxbg.json"

# Conditions Contributing to COVID-19 Deaths, by State and Age, Provisional 2020-2022 NCHS
"https://data.cdc.gov/resource/hk9y-quqm.json"

# COVID-19 Case Surveillance Public Use Data with Geography Case Surveillance
"https://data.cdc.gov/resource/n8mc-b4w4.json"

# COVID-19 Case Surveillance Public Use DataCase Surveillance
"https://data.cdc.gov/resource/vbim-akqf.json"

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cdc.gov", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cdc.gov,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("hk9y-quqm", limit=50000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#                     data_as_of               start_date  \
# 0      2022-03-13T00:00:00.000  2020-01-01T00:00:00.000
# 1      2022-03-13T00:00:00.000  2020-01-01T00:00:00.000
# 2      2022-03-13T00:00:00.000  2020-01-01T00:00:00.000
# 3      2022-03-13T00:00:00.000  2020-01-01T00:00:00.000
# 4      2022-03-13T00:00:00.000  2020-01-01T00:00:00.000
# ...                        ...                      ...
# 49995  2022-03-13T00:00:00.000  2021-07-01T00:00:00.000
# 49996  2022-03-13T00:00:00.000  2021-08-01T00:00:00.000
# 49997  2022-03-13T00:00:00.000  2021-09-01T00:00:00.000
# 49998  2022-03-13T00:00:00.000  2021-10-01T00:00:00.000
# 49999  2022-03-13T00:00:00.000  2021-11-01T00:00:00.000
#
#                       end_date     group          state       condition_group  \
# 0      2022-03-12T00:00:00.000  By Total  United States  Respiratory diseases
# 1      2022-03-12T00:00:00.000  By Total  United States  Respiratory diseases
# 2      2022-03-12T00:00:00.000  By Total  United States  Respiratory diseases
# 3      2022-03-12T00:00:00.000  By Total  United States  Respiratory diseases
# 4      2022-03-12T00:00:00.000  By Total  United States  Respiratory diseases
# ...                        ...       ...            ...                   ...
# 49995  2021-07-31T00:00:00.000  By Month  United States  Respiratory diseases
# 49996  2021-08-31T00:00:00.000  By Month  United States  Respiratory diseases
# 49997  2021-09-30T00:00:00.000  By Month  United States  Respiratory diseases
# 49998  2021-10-31T00:00:00.000  By Month  United States  Respiratory diseases
# 49999  2021-11-30T00:00:00.000  By Month  United States  Respiratory diseases
#
#                                 condition icd10_codes age_group  \
# 0                 Influenza and pneumonia     J09-J18      0-24
# 1                 Influenza and pneumonia     J09-J18     25-34
# 2                 Influenza and pneumonia     J09-J18     35-44
# 3                 Influenza and pneumonia     J09-J18     45-54
# 4                 Influenza and pneumonia     J09-J18     55-64
# ...                                   ...         ...       ...
# 49995  Chronic lower respiratory diseases     J40-J47     25-34
# 49996  Chronic lower respiratory diseases     J40-J47     25-34
# 49997  Chronic lower respiratory diseases     J40-J47     25-34
# 49998  Chronic lower respiratory diseases     J40-J47     25-34
# 49999  Chronic lower respiratory diseases     J40-J47     25-34
#
#       covid_19_deaths number_of_mentions flag  year month
# 0                1266               1323  NaN   NaN   NaN
# 1                5321               5520  NaN   NaN   NaN
# 2               14036              14589  NaN   NaN   NaN
# 3               34981              36298  NaN   NaN   NaN
# 4               76305              78962  NaN   NaN   NaN
# ...               ...                ...  ...   ...   ...
# 49995              10                 10  NaN  2021     7
# 49996              40                 42  NaN  2021     8
# 49997              42                 42  NaN  2021     9
# 49998              21                 22  NaN  2021    10
# 49999              17                 18  NaN  2021    11
#
# [50000 rows x 14 columns]

# %% [markdown]
# This seems to work but to get all the data I need an API token

# %%
a= results_df['state'].unique()
a.sort()
a
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'New York City',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Puerto Rico', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'United States', 'Utah',
#        'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin',
#        'Wyoming'], dtype=object)

# %%
# Or passed as a URL perameter
https://data.seattle.gov/resource/kzjm-xkqj.json?$$app_token=APP_TOKEN

# %%
with open("APP_TOKEN.txt",'r') as f:
    API_TOKEN=f.read()

# %%
client = Socrata("data.cdc.gov", API_TOKEN)

# %%
results = client.get("9mfq-cb36", limit=50000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df
# Out:
#                submission_date state tot_cases conf_cases prob_cases new_case  \
# 0      2021-03-11T00:00:00.000    KS    297229   241035.0      56194      0.0
# 1      2021-02-12T00:00:00.000    UT    359641   359641.0          0   1060.0
# 2      2020-02-04T00:00:00.000    AR         0        NaN        NaN      0.0
# 3      2020-08-22T00:00:00.000    AR     56199        NaN        NaN    547.0
# 4      2021-12-06T00:00:00.000    MP      1104     1104.0          0      0.0
# ...                        ...   ...       ...        ...        ...      ...
# 47155  2020-06-07T00:00:00.000    SD      5438        NaN        NaN     71.0
# 47156  2021-04-30T00:00:00.000    SD    122660        NaN        NaN    128.0
# 47157  2020-04-06T00:00:00.000    NM       686        NaN        NaN     62.0
# 47158  2021-03-10T00:00:00.000    SD    113962        NaN        NaN    209.0
# 47159  2021-05-27T00:00:00.000    OH   1100312   921199.0     179113    732.0
#
#       pnew_case tot_death new_death pnew_death               created_at  \
# 0             0      4851       0.0          0  2021-03-12T15:20:13.190
# 1             0      1785      11.0          2  2021-02-13T14:50:08.565
# 2           NaN         0       0.0        NaN  2020-03-26T16:22:39.452
# 3             0       674      11.0          0  2020-08-23T14:15:28.102
# 4             0         5       2.0          0  2021-12-08T00:00:00.000
# ...         ...       ...       ...        ...                      ...
# 47155         0        65       0.0          1  2020-06-08T14:55:08.000
# 47156        17      1967       5.0          1  2021-05-01T13:43:22.175
# 47157         0        12       0.0          0  2020-04-08T00:00:00.000
# 47158        37      1904       3.0          0  2021-03-11T15:36:21.295
# 47159       196     19753       0.0          0  2021-05-28T13:29:21.497
#
#       consent_cases consent_deaths conf_death prob_death
# 0             Agree            N/A        NaN        NaN
# 1             Agree          Agree     1729.0         56
# 2         Not agree      Not agree        NaN        NaN
# 3         Not agree      Not agree        NaN        NaN
# 4             Agree          Agree        5.0          0
# ...             ...            ...        ...        ...
# 47155           N/A          Agree       64.0          1
# 47156           N/A          Agree     1601.0        366
# 47157           N/A      Not agree        NaN        NaN
# 47158           N/A          Agree     1546.0        358
# 47159         Agree          Agree    19753.0          0
#
# [47160 rows x 15 columns]

# %%
a= results_df['state'].unique()
a.sort()
a
# Out:
# array(['AK', 'AL', 'AR', 'AS', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL',
#        'FSM', 'GA', 'GU', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA',
#        'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MP', 'MS', 'MT', 'NC', 'ND',
#        'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'NYC', 'OH', 'OK', 'OR', 'PA',
#        'PR', 'PW', 'RI', 'RMI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VI',
#        'VT', 'WA', 'WI', 'WV', 'WY'], dtype=object)

# %%
# 60 "states" which include New York City and Washington DC and Puerto Rico.  Don't know what PW and RMI are.  I think GU is Guam, but FSM?  Flying Speghetti Monster?
